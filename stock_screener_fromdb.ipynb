# %%
import pandas as pd 
import sqlalchemy
import ta

# %%
#Extract data from established postgres db
db_pass = 'Jalisco1995?'
demo_engine = sqlalchemy.create_engine(f'postgresql://postgres:{db_pass}@localhost/stock_data')

# %%
names = pd.read_sql("""SELECT tablename FROM pg_tables where schemaname='public' """,demo_engine)

# %%
names
# Out:
#    tablename
# 0        MMM
# 1        AXP
# 2       AMGN
# 3       AAPL
# 4         BA
# 5        CAT
# 6        CVX
# 7       CSCO
# 8         KO
# 9        DIS
# 10       DOW
# 11        GS
# 12        HD
# 13       HON
# 14       IBM
# 15      INTC
# 16       JNJ
# 17       JPM
# 18       MCD
# 19       MRK
# 20      MSFT
# 21       NKE
# 22        PG
# 23       CRM
# 24       TRV
# 25       UNH
# 26        VZ
# 27         V
# 28       WBA
# 29       WMT

# %%
names = names.tablename.to_list()

# %%
#extract data fields fromm sql tables and store aggregate data into df list
framelist = []

for name in names:
    framelist.append(pd.read_sql(f'SELECT "Date", "Close" FROM "{name}"',demo_engine))

# %%
framelist
# Out:
# [            Date       Close
#  0     1962-01-02    4.156250
#  1     1962-01-03    4.187500
#  2     1962-01-04    4.187500
#  3     1962-01-05    4.078125
#  4     1962-01-08    4.054688
#  ...          ...         ...
#  15210 2022-06-03  145.970001
#  15211 2022-06-06  146.210007
#  15212 2022-06-07  146.869995
#  15213 2022-06-08  145.419998
#  15214 2022-06-09  144.179993
#
#  [15215 rows x 2 columns],
#              Date       Close
#  0     1972-06-01    3.693287
#  1     1972-06-02    3.677195
#  2     1972-06-05    3.604777
#  3     1972-06-06    3.411664
#  4     1972-06-07    3.371432
#  ...          ...         ...
#  12505 2022-06-03  166.830002
#  12506 2022-06-06  167.020004
#  12507 2022-06-07  168.690002
#  12508 2022-06-08  165.960007
#  12509 2022-06-09  160.979996
#
#  [12510 rows x 2 columns],
#             Date       Close
#  0    1983-06-17    0.343750
#  1    1983-06-20    0.302083
#  2    1983-06-21    0.302083
#  3    1983-06-22    0.312500
#  4    1983-06-23    0.312500
#  ...         ...         ...
#  9819 2022-06-03  248.449997
#  9820 2022-06-06  245.440002
#  9821 2022-06-07  246.410004
#  9822 2022-06-08  245.479996
#  9823 2022-06-09  241.750000
#
#  [9824 rows x 2 columns],
#              Date       Close
#  0     1980-12-12    0.128348
#  1     1980-12-15    0.121652
#  2     1980-12-16    0.112723
#  3     1980-12-17    0.115513
#  4     1980-12-18    0.118862
#  ...          ...         ...
#  10457 2022-06-03  145.380005
#  10458 2022-06-06  146.139999
#  10459 2022-06-07  148.710007
#  10460 2022-06-08  147.960007
#  10461 2022-06-09  142.639999
#
#  [10462 rows x 2 columns],
#              Date       Close
#  0     1962-01-02    0.823045
#  1     1962-01-03    0.839506
#  2     1962-01-04    0.831276
#  3     1962-01-05    0.814815
#  4     1962-01-08    0.816872
#  ...          ...         ...
#  15210 2022-06-03  139.250000
#  15211 2022-06-06  139.240005
#  15212 2022-06-07  140.820007
#  15213 2022-06-08  139.630005
#  15214 2022-06-09  133.729996
#
#  [15215 rows x 2 columns],
#              Date       Close
#  0     1962-01-02    1.604167
#  1     1962-01-03    1.619792
#  2     1962-01-04    1.661458
#  3     1962-01-05    1.677083
#  4     1962-01-08    1.687500
#  ...          ...         ...
#  15210 2022-06-03  222.899994
#  15211 2022-06-06  223.630005
#  15212 2022-06-07  227.100006
#  15208 2022-06-03  145.889999
#  15209 2022-06-06  145.320007
#  15210 2022-06-07  146.940002
#  15211 2022-06-08  145.110001
#  15212 2022-06-09  142.490005
#
#  [15213 rows x 2 columns],
#             Date       Close
#  0    2004-06-23    4.300000
#  1    2004-06-24    4.190000
#  2    2004-06-25    3.950000
#  3    2004-06-28    4.000000
#  4    2004-06-29    4.100000
#  ...         ...         ...
#  4519 2022-06-03  184.910004
#  4520 2022-06-06  182.869995
#  4521 2022-06-07  187.149994
#  4522 2022-06-08  189.190002
#  4523 2022-06-09  187.110001
#
#  [4524 rows x 2 columns],
#              Date       Close
#  0     1975-11-17    8.718750
#  1     1975-11-18    8.968750
#  2     1975-11-19    8.562500
#  3     1975-11-20    8.437500
#  4     1975-11-21    8.437500
#  ...          ...         ...
#  11723 2022-06-03  174.190002
#  11724 2022-06-06  176.979996
#  11725 2022-06-07  178.639999
#  11726 2022-06-08  175.970001
#  11727 2022-06-09  171.529999
#
#  [11728 rows x 2 columns],
#             Date       Close
#  0    1984-10-17    0.144531
#  1    1984-10-18    0.148438
#  2    1984-10-19    0.144531
#  3    1984-10-22    0.144531
#  4    1984-10-23    0.140625
#  ...         ...         ...
#  9478 2022-06-03  485.609985
#  9479 2022-06-06  490.179993
#  9480 2022-06-07  497.100006
#  9481 2022-06-08  493.529999
#  9482 2022-06-09  489.429993
#
#  [9483 rows x 2 columns],
#             Date      Close
#  0    1983-11-21   7.897178
#  1    1983-11-22   7.869074
#  2    1983-11-23   7.826918
#  3    1983-11-25   7.742607
#  4    1983-11-28   7.531828
#  ...         ...        ...
#  9713 2022-06-03  50.810001
#  9714 2022-06-06  51.240002
#  9715 2022-06-07  51.650002
#  9716 2022-06-08  51.549999
#  9717 2022-06-09  50.939999
#
#  [9718 rows x 2 columns],
#             Date       Close
#  0    2008-03-19   14.125000
#  1    2008-03-20   16.087500
#  2    2008-03-24   14.932500
#  3    2008-03-25   15.812500
#  4    2008-03-26   15.990000
#  ...         ...         ...
#  3578 2022-06-03  212.649994
#  3579 2022-06-06  212.940002
#  3580 2022-06-07  214.500000
#  3581 2022-06-08  213.500000
#  3582 2022-06-09  206.110001
#
#  [3583 rows x 2 columns],
#              Date      Close
#  0     1980-03-17   0.208984
#  1     1980-03-18   0.208008
#  2     1980-03-19   0.213867
#  3     1980-03-20   0.212891
#  4     1980-03-21   0.213867
#  ...          ...        ...
#  10645 2022-06-03  43.139999
#  10646 2022-06-06  43.389999
#  10647 2022-06-07  43.000000
#  10648 2022-06-08  42.599998
#  10649 2022-06-09  41.720001
#
#  [10650 rows x 2 columns],
#              Date       Close
#  0     1972-08-25    0.064453
#  1     1972-08-28    0.064209
#  2     1972-08-29    0.063477
#  3     1972-08-30    0.063477
#  4     1972-08-31    0.062500
#  ...          ...         ...
#  12531 2022-06-03  125.320000
#  12532 2022-06-06  124.870003
#  12533 2022-06-07  123.370003
#  12534 2022-06-08  122.300003
#  12535 2022-06-09  121.019997
#
#  [12536 rows x 2 columns]]

# %%
#function to compute the MACD (moving average convergence divergence)
def MACDdecision(df):
    df['MACD_diff']  = ta.trend.macd_diff(df.Close)
    #The decision to buy will be determinded as based to a delta greater than 0 on the current day and smaller than 0 on the day before
    df.loc[(df.MACD_diff > 0) & (df.MACD_diff.shift(1) < 0), 'Decision_MACD'] = 'Buy'

# %%
#fucntion for RSI (relative strenght index) and SMA (simple moving average)
def RSI_SMAdecision(df):
    df['RSI'] = ta.momentum.rsi(df.Close, window=10)
    df['SMA200'] = ta.trend.sma_indicator(df.Close, window=200)
    #check for when the price is above the 200 day moving average and the RSI is below 30
    df.loc[(df.Close > df.SMA200) & (df.RSI < 30), 'Decision_RSI_SMA'] = 'Buy'

# %%
#loop over all 30 dfs in list to apply functions 
for frame in framelist:
    MACDdecision(frame)
    RSI_SMAdecision(frame)

# %%
framelist[0]
# Out:
#             Date       Close  MACD_diff Decision_MACD        RSI     SMA200  \
# 0     1962-01-02    4.156250        NaN           NaN        NaN        NaN
# 1     1962-01-03    4.187500        NaN           NaN        NaN        NaN
# 2     1962-01-04    4.187500        NaN           NaN        NaN        NaN
# 3     1962-01-05    4.078125        NaN           NaN        NaN        NaN
# 4     1962-01-08    4.054688        NaN           NaN        NaN        NaN
# ...          ...         ...        ...           ...        ...        ...
# 15210 2022-06-03  145.970001  -0.035269           NaN  44.973851  167.03970
# 15211 2022-06-06  146.210007  -0.078015           NaN  45.753619  166.79395
# 15212 2022-06-07  146.869995  -0.054632           NaN  48.004909  166.55750
# 15213 2022-06-08  145.419998  -0.125557           NaN  43.588947  166.31120
# 15214 2022-06-09  144.179993  -0.238188           NaN  40.085163  166.05835
#
#       Decision_RSI_SMA
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 15210              NaN
# 15211              NaN
# 15212              NaN
# 15213              NaN
# 15214              NaN
#
# [15215 rows x 7 columns]

# %%
for name,frame in zip(names,framelist):
    if frame['Decision_MACD'].iloc[-1] == 'Buy':
        print("Buying signal MACD for " + name)
    if frame['Decision_RSI_SMA'].iloc[-1] == 'Buy':
        print("Buying signal RSI_SMA for " + name)

# %%
goal = framelist[0]
goal.head()
# Out:
#         Date     Close  MACD_diff Decision_MACD  RSI  SMA200 Decision_RSI_SMA
# 0 1962-01-02  4.156250        NaN           NaN  NaN     NaN              NaN
# 1 1962-01-03  4.187500        NaN           NaN  NaN     NaN              NaN
# 2 1962-01-04  4.187500        NaN           NaN  NaN     NaN              NaN
# 3 1962-01-05  4.078125        NaN           NaN  NaN     NaN              NaN
# 4 1962-01-08  4.054688        NaN           NaN  NaN     NaN              NaN

# %%
goal[(goal.Decision_RSI_SMA == 'Buy')]
# Out:
#             Date       Close  MACD_diff Decision_MACD        RSI      SMA200  \
# 293   1963-03-01    3.539063  -0.023281           NaN  28.779385    3.300860
# 294   1963-03-04    3.539063  -0.025770           NaN  28.779385    3.298516
# 355   1963-05-29    3.664063  -0.010158           NaN  29.483742    3.483399
# 363   1963-06-11    3.570313  -0.008855           NaN  20.946731    3.497578
# 364   1963-06-12    3.585938  -0.009137           NaN  26.800139    3.498633
# ...          ...         ...        ...           ...        ...         ...
# 14858 2021-01-11  165.199997  -1.156581           NaN  27.619058  160.414000
# 14966 2021-06-16  196.910004  -0.802052           NaN  27.908835  180.155800
# 14967 2021-06-17  195.139999  -1.058009           NaN  24.159815  180.316400
# 14968 2021-06-18  191.600006  -1.393487           NaN  18.605770  180.450400
# 14971 2021-06-23  192.360001  -1.213326           NaN  29.499108  180.856000
#
#       Decision_RSI_SMA
# 293                Buy
# 294                Buy
# 355                Buy
# 363                Buy
# 364                Buy
# ...                ...
# 14858              Buy
# 14966              Buy
# 14967              Buy
# 14968              Buy
# 14971              Buy
#
# [213 rows x 7 columns]
