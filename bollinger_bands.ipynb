# %% [markdown]
# ### Bollinger Bands

# %%
import yfinance as yf 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = yf.download('MSFT', start='2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  215.434967
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  215.642792
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  210.051300
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  216.028748
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  217.344955
# ...                ...         ...         ...         ...         ...
# 2022-02-14  293.769989  296.760010  291.350006  295.000000  294.391296
# 2022-02-15  300.010010  300.799988  297.019989  300.470001  299.850006
# 2022-02-16  298.369995  300.869995  293.679993  299.500000  299.500000
# 2022-02-17  296.359985  296.799988  290.000000  290.730011  290.730011
# 2022-02-18  293.049988  293.859985  286.309998  287.929993  287.929993
#
#               Volume
# Date
# 2021-01-04  37130100
# 2021-01-05  23823000
# 2021-01-06  35930700
# 2021-01-07  27694500
# 2021-01-08  22956200
# ...              ...
# 2022-02-14  36359500
# 2022-02-15  27379500
# 2022-02-16  29982100
# 2022-02-17  32461600
# 2022-02-18  34223200
#
# [286 rows x 6 columns]

# %%
#calculate simple moving average 
df['SMA'] = df.Close.rolling(window=20).mean()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  215.434967
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  215.642792
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  210.051300
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  216.028748
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  217.344955
# ...                ...         ...         ...         ...         ...
# 2022-02-14  293.769989  296.760010  291.350006  295.000000  294.391296
# 2022-02-15  300.010010  300.799988  297.019989  300.470001  299.850006
# 2022-02-16  298.369995  300.869995  293.679993  299.500000  299.500000
# 2022-02-17  296.359985  296.799988  290.000000  290.730011  290.730011
# 2022-02-18  293.049988  293.859985  286.309998  287.929993  287.929993
#
#               Volume         SMA
# Date
# 2021-01-04  37130100         NaN
# 2021-01-05  23823000         NaN
# 2021-01-06  35930700         NaN
# 2021-01-07  27694500         NaN
# 2021-01-08  22956200         NaN
# ...              ...         ...
# 2022-02-14  36359500  302.140500
# 2022-02-15  27379500  302.031500
# 2022-02-16  29982100  301.840001
# 2022-02-17  32461600  301.296501
# 2022-02-18  34223200  300.891501
#
# [286 rows x 7 columns]

# %%
df['stddev'] = df.Close.rolling(window=20).std()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  215.434967
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  215.642792
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  210.051300
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  216.028748
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  217.344955
# ...                ...         ...         ...         ...         ...
# 2022-02-14  293.769989  296.760010  291.350006  295.000000  294.391296
# 2022-02-15  300.010010  300.799988  297.019989  300.470001  299.850006
# 2022-02-16  298.369995  300.869995  293.679993  299.500000  299.500000
# 2022-02-17  296.359985  296.799988  290.000000  290.730011  290.730011
# 2022-02-18  293.049988  293.859985  286.309998  287.929993  287.929993
#
#               Volume         SMA    stddev
# Date
# 2021-01-04  37130100         NaN       NaN
# 2021-01-05  23823000         NaN       NaN
# 2021-01-06  35930700         NaN       NaN
# 2021-01-07  27694500         NaN       NaN
# 2021-01-08  22956200         NaN       NaN
# ...              ...         ...       ...
# 2022-02-14  36359500  302.140500  6.437857
# 2022-02-15  27379500  302.031500  6.447225
# 2022-02-16  29982100  301.840001  6.463486
# 2022-02-17  32461600  301.296501  6.925251
# 2022-02-18  34223200  300.891501  7.465252
#
# [286 rows x 8 columns]

# %%
df['Upper'] = df.SMA + 2* df.stddev
df['Lower'] = df.SMA - 2* df.stddev

df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  215.434967
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  215.642792
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  210.051300
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  216.028748
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  217.344955
# ...                ...         ...         ...         ...         ...
# 2022-02-14  293.769989  296.760010  291.350006  295.000000  294.391296
# 2022-02-15  300.010010  300.799988  297.019989  300.470001  299.850006
# 2022-02-16  298.369995  300.869995  293.679993  299.500000  299.500000
# 2022-02-17  296.359985  296.799988  290.000000  290.730011  290.730011
# 2022-02-18  293.049988  293.859985  286.309998  287.929993  287.929993
#
#               Volume         SMA    stddev       Upper       Lower
# Date
# 2021-01-04  37130100         NaN       NaN         NaN         NaN
# 2021-01-05  23823000         NaN       NaN         NaN         NaN
# 2021-01-06  35930700         NaN       NaN         NaN         NaN
# 2021-01-07  27694500         NaN       NaN         NaN         NaN
# 2021-01-08  22956200         NaN       NaN         NaN         NaN
# ...              ...         ...       ...         ...         ...
# 2022-02-14  36359500  302.140500  6.437857  315.016214  289.264786
# 2022-02-15  27379500  302.031500  6.447225  314.925950  289.137051
# 2022-02-16  29982100  301.840001  6.463486  314.766973  288.913029
# 2022-02-17  32461600  301.296501  6.925251  315.147003  287.446000
# 2022-02-18  34223200  300.891501  7.465252  315.822005  285.960996
#
# [286 rows x 10 columns]

# %%
#Define buying signal; when lower band is above the close price
df['Buy_Signal'] = np.where(df.Lower > df.Close, True, False)

# %%
#Define selling signal, when the upper band is below the close price 
df['Sell_Signal'] = np.where(df.Upper < df.Close, True, False)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  222.529999  223.000000  214.809998  217.690002  215.434967
# 2021-01-05  217.259995  218.520004  215.699997  217.899994  215.642792
# 2021-01-06  212.169998  216.490005  211.940002  212.250000  210.051300
# 2021-01-07  214.039993  219.339996  213.710007  218.289993  216.028748
# 2021-01-08  218.679993  220.580002  217.029999  219.619995  217.344955
# ...                ...         ...         ...         ...         ...
# 2022-02-14  293.769989  296.760010  291.350006  295.000000  294.391296
# 2022-02-15  300.010010  300.799988  297.019989  300.470001  299.850006
# 2021-02-04       False        False
# 2021-02-05       False        False
# ...                ...          ...
# 2022-02-14       False        False
# 2022-02-15       False        False
# 2022-02-16       False        False
# 2022-02-17       False        False
# 2022-02-18       False        False
#
# [267 rows x 12 columns]

# %%
plt.rcParams["figure.figsize"] = (12,6)
plt.plot(df[['Close','SMA','Upper','Lower']])
plt.scatter(df.index[df.Buy_Signal],df[df.Buy_Signal].Close, marker='^', color='r')
plt.scatter(df.index[df.Sell_Signal],df[df.Sell_Signal].Close, marker='^', color='r')
plt.fill_between(df.index,df.Upper,df.Lower,color='grey',alpha=0.3)
plt.legend(['Close','SMA','Upper','Lower'])
plt.show()

# %%
#Create a strategy through which a sell or a purchase is committed uppon the first respective signal along the time series 
buys = []
sells = []
open_pos = False

for i in range(len(df)):
    if df.Lower[i] > df.Close[i]:
        if open_pos == False:
            buys.append(i)
            open_pos = True 
    elif df.Upper[i] < df.Close[i]:
        if open_pos:
            sells.append(i)
            open_pos = False

# %%
buys
# Out:
# [17, 64, 160, 213]

# %%
sells
# Out:
# [42, 90, 187]

# %%
plt.rcParams["figure.figsize"] = (12,6)
plt.plot(df[['Close','SMA','Upper','Lower']])
plt.scatter(df.iloc[buys].index, df.iloc[buys].Close, marker='^', color='r')
plt.scatter(df.iloc[sells].index, df.iloc[sells].Close, marker='^', color='r')
plt.fill_between(df.index,df.Upper,df.Lower,color='grey',alpha=0.3)
plt.legend(['Close','SMA','Upper','Lower'])
plt.show()

# %%
merged = pd.concat([df.iloc[buys].Close, df.iloc[sells].Close], axis=1)
merged
# Out:
#                  Close       Close
# Date
# 2021-02-25  228.990005         NaN
# 2021-04-01         NaN  242.350006
# 2021-05-04  247.789993         NaN
# 2021-06-10         NaN  257.239990
# 2021-09-20  294.299988         NaN
# 2021-10-27         NaN  323.170013
# 2021-12-03  323.010010         NaN

# %%
merged.columns = ['Buys','Sells']
merged
# Out:
#                   Buys       Sells
# Date
# 2021-02-25  228.990005         NaN
# 2021-04-01         NaN  242.350006
# 2021-05-04  247.789993         NaN
# 2021-06-10         NaN  257.239990
# 2021-09-20  294.299988         NaN
# 2021-10-27         NaN  323.170013
# 2021-12-03  323.010010         NaN

# %%
totalprofit = merged.shift(-1).Sells - merged.Buys
totalprofit
# Out:
# Date
# 2021-02-25    13.360001
# 2021-04-01          NaN
# 2021-05-04     9.449997
# 2021-06-10          NaN
# 2021-09-20    28.870026
# 2021-10-27          NaN
# 2021-12-03          NaN
# dtype: float64

# %%
#relative profits
relprofits = (merged.shift(-1).Sells - merged.Buys)/merged.Buys
relprofits
# Out:
# Date
# 2021-02-25    0.058343
# 2021-04-01         NaN
# 2021-05-04    0.038137
# 2021-06-10         NaN
# 2021-09-20    0.098097
# 2021-10-27         NaN
# 2021-12-03         NaN
# dtype: float64

# %%
relprofits.mean()
# Out:
# 0.06485918408130124
